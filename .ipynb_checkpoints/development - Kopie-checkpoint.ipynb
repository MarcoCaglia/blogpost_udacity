# %% [markdown]
# # Kaggle Competition: Advanced Regression Techniques
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques
# ## Outline
# 1. Basic Exploration and EDA
# 2. Feature Engineering
# 5. Modelling
# 6. Submission

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PolynomialFeatures, RobustScaler, LabelEncoder
from sklearn.model_selection import GridSearchCV, KFold, cross_val_score
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.decomposition import TruncatedSVD, PCA
from sklearn.metrics import r2_score
import xgboost as xgb
# %matplotlib inline

# %%
df_train = pd.read_csv('train.csv',index_col = 'Id')
df_test = pd.read_csv('test.csv',index_col = 'Id')
conserve_test_ids = df_train.shape[0]
df = pd.concat((df_train, df_test))
# Out:
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Basic Exploration and EDA

# %%
# Show dataframe attributes
df.shape
# Out:
# (2919, 80)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
# 1stFlrSF         2919 non-null int64
# 2ndFlrSF         2919 non-null int64
# 3SsnPorch        2919 non-null int64
# Alley            198 non-null object
# BedroomAbvGr     2919 non-null int64
# BldgType         2919 non-null object
# BsmtCond         2837 non-null object
# BsmtExposure     2837 non-null object
# BsmtFinSF1       2918 non-null float64
# BsmtFinSF2       2918 non-null float64
# BsmtFinType1     2840 non-null object
# BsmtFinType2     2839 non-null object
# BsmtFullBath     2917 non-null float64
# BsmtHalfBath     2917 non-null float64
# BsmtQual         2838 non-null object
# BsmtUnfSF        2918 non-null float64
# CentralAir       2919 non-null object
# Condition1       2919 non-null object
# Condition2       2919 non-null object
# Electrical       2918 non-null object
# EnclosedPorch    2919 non-null int64
# ExterCond        2919 non-null object
# ExterQual        2919 non-null object
# Exterior1st      2918 non-null object
# Exterior2nd      2918 non-null object
# Fence            571 non-null object
# FireplaceQu      1499 non-null object
# Fireplaces       2919 non-null int64
# Foundation       2919 non-null object
# FullBath         2919 non-null int64
# Functional       2917 non-null object
# GarageArea       2918 non-null float64
# GarageCars       2918 non-null float64
# GarageCond       2760 non-null object
# GarageFinish     2760 non-null object
# GarageQual       2760 non-null object
# GarageType       2762 non-null object
# GarageYrBlt      2760 non-null float64
# GrLivArea        2919 non-null int64
# HalfBath         2919 non-null int64
# Heating          2919 non-null object
# HeatingQC        2919 non-null object
# HouseStyle       2919 non-null object
# KitchenAbvGr     2919 non-null int64
# KitchenQual      2918 non-null object
# LandContour      2919 non-null object
# LandSlope        2919 non-null object
# LotArea          2919 non-null int64
# LotConfig        2919 non-null object
# LotFrontage      2433 non-null float64
# LotShape         2919 non-null object
# LowQualFinSF     2919 non-null int64
# MSSubClass       2919 non-null int64
# MSZoning         2915 non-null object
# MasVnrArea       2896 non-null float64
# MasVnrType       2895 non-null object
# MiscFeature      105 non-null object
# MiscVal          2919 non-null int64
# MoSold           2919 non-null int64
# Neighborhood     2919 non-null object
# OpenPorchSF      2919 non-null int64
# OverallCond      2919 non-null int64
# OverallQual      2919 non-null int64
# PavedDrive       2919 non-null object
# PoolArea         2919 non-null int64
# PoolQC           10 non-null object
# RoofMatl         2919 non-null object
# RoofStyle        2919 non-null object
# SaleCondition    2919 non-null object
# SalePrice        1460 non-null float64
# SaleType         2918 non-null object
# ScreenPorch      2919 non-null int64
# Street           2919 non-null object
# TotRmsAbvGrd     2919 non-null int64
# TotalBsmtSF      2918 non-null float64
# Utilities        2917 non-null object
# WoodDeckSF       2919 non-null int64
# YearBuilt        2919 non-null int64
# YearRemodAdd     2919 non-null int64
# YrSold           2919 non-null int64
# dtypes: float64(12), int64(25), object(43)
# memory usage: 1.8+ MB

# %%
# Examination of numerical variables (correlation to target)
num_features = [feature for feature in df.columns if df[feature].dtype!= 'object']

cols = 4
rows = 10

fig, ax = plt.subplots(rows,cols,figsize=(rows*3,cols*10))
i=0

for row in range(rows):
    for col in range(cols):
        if i<len(num_features):
            corr, p_val = h1_correlation(df,num_features[i],'SalePrice',permutations=1*10**1)
            sns.regplot(x=num_features[i],y='SalePrice',data=df,order=1,ax=ax[row][col]).set_title('Corr: {}\np-value: {}'.format(corr,p_val))
            i+=1
            
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1e6fbcb61a78> in <module>
#      11     for col in range(cols):
#      12         if i<len(num_features):
# ---> 13             corr, p_val = h1_correlation(df,num_features[i],'SalePrice',permutations=1*10**1)
#      14             sns.regplot(x=num_features[i],y='SalePrice',data=df,order=1,ax=ax[row][col]).set_title('Corr: {}\np-value: {}'.format(corr,p_val))
#      15             i+=1
#
# NameError: name 'h1_correlation' is not defined

# %%
# Examination of non-numerical features (correlation matrix)

sns.heatmap(df.corr())

# %%
# Examination of numerical features (distributions)
cols = 4
rows = 10

fig, ax = plt.subplots(rows,cols,figsize=(rows*3,cols*10))
i=0

for row in range(rows):
    for col in range(cols):
        if i<len(num_features):
            sns.distplot(df[num_features[i]].dropna(),ax = ax[row][col]).set_title('p-value: {}'.format(stats.shapiro(df[num_features[i]].dropna())[1]))
            i+=1
            
plt.tight_layout()
plt.show()

# %%
# Examination of non-numerical features
non_numerical_features = [feature for feature in df.columns if feature not in num_features]

cols = 3
rows = 15

fig,ax = plt.subplots(rows,cols,figsize=(cols*5,rows*3))
i = 0

for row in range(rows):
    for col in range(cols):
        if i<len(non_numerical_features):
            cat_means = df.groupby(non_numerical_features[i])[[non_numerical_features[i],'SalePrice']].mean()
            target_cats = cat_means.index.tolist()
            target_means = list(cat_means.iloc[:,0])
            ordered_list = sorted(zip(target_means,target_cats),key=lambda x: x[0])
            order = np.array([y for x,y in ordered_list])
            sns.boxplot(x=non_numerical_features[i],y='SalePrice',data=df,order=order,ax=ax[row][col])
            i+=1
            
plt.tight_layout()

plt.show()

# %%
# Examination of missing data
missing_report = pd.DataFrame(df.isnull().sum().sort_values(ascending=False),columns=['missing_values'])
missing_report['missing_values_rel'] = missing_report['missing_values']/df.shape[0]
        
for index,value in missing_report.iterrows():
    if value[0]==0:
        missing_report.drop(index,inplace=True)
        
missing_report

# %% [markdown]
# The previous evaluation has shown that:
# - There are some numerical features, that should be encoded as non-numerical features.
# - Most features are far from normally distributed.Those distributions will have to be shifted.
# - Missing values have to be imputed.
# - There is some multicollinearity in amongst the features in the dataset.
#
# ### Feature Engineering

# %%
## Imputation of missing values
# PoolQC: NA means no pool, therefore None is imputed as its own category.
df['PoolQC'] = df['PoolQC'].fillna('None')

# MiscFeature: NA means, that there is no specific additional feature. Therefore None is imputed as its own category.
df['MiscFeature'] = df['MiscFeature'].fillna('None')

# Alley: NA means no alley access
df['Alley'] = df['Alley'].fillna('None')

# Fence: NA means no fence
df['Fence'] = df['Fence'].fillna('None')

# FireplaceQu: NA means no fireplace
df['FireplaceQu'] = df['FireplaceQu'].fillna('None')

# GarageType: NA means no garage (garage features are treated accordingly)
df['GarageType'] = df['GarageType'].fillna('None')
df['GarageCond'] = df['GarageCond'].fillna('None')
df['GarageFinish'] = df['GarageFinish'].fillna('None')
df['GarageQual'] = df['GarageQual'].fillna('None')
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(0)

# BsmtFinType2: NA means no basement (related features are treated accordingly)
df['BsmtFinType2'] = df['BsmtFinType2'].fillna('None')
df['BsmtExposure'] = df['BsmtExposure'].fillna('None')
df['BsmtQual'] = df['BsmtQual'].fillna('None')
df['BsmtCond'] = df['BsmtCond'].fillna('None')
df['BsmtFinType1'] = df['BsmtFinType1'].fillna('None')

# MasVnrArea: Object can have no veneer area
df['MasVnrArea'] = df['MasVnrArea'].fillna(0)

# MasVnrType: See above
df['MasVnrType'] = df['MasVnrType'].fillna('None')

# Electrical: As the most frequent value by far is SBrkr, and only one single value is affected, SBkrkr can be imputed.
df['Electrical'] = df['Electrical'].fillna('SBrkr')

# MSZoning: Assign Mode of data set to missing values
df['MSZoning'] = df['MSZoning'].fillna(df['MSZoning'].mode()[0])
assert df['MSZoning'].isnull().sum()==0

# Utilities: The overwhelming majority of train observations are 'AllPub', therefore, that value is imputed
df['Utilities'] = df['Utilities'].fillna('AllPub')

# Functional: Similar to utilities but less pronounced → under the assumption, that there is no systematic reason for a certain value to
# be missing, the mode is the best option again
df['Functional'] = df['Functional'].fillna(df['Functional'].mode()[0])

# Exterior2nd: See 'Functional'
df['Exterior2nd'] = df['Exterior2nd'].fillna(df['Exterior2nd'].mode()[0])

# SaleType: See 'Functional'
df['SaleType'] = df['SaleType'].fillna(df['SaleType'].mode()[0])

# Exterior1st: See 'Functional'
df['Exterior1st'] = df['Exterior1st'].fillna(df['Exterior1st'].mode()[0])

# KitchenQual: See 'Functional'
df['KitchenQual'] = df['KitchenQual'].fillna(df['KitchenQual'].mode()[0])

# GarageCars: Similar to other Garage related features
df['GarageCars'] = df['GarageCars'].fillna(0)

# GarageArea: Similar to other Garage related features
df['GarageArea'] = df['GarageArea'].fillna(0)

# Bsmt Features: Similar consideration as in Training set (np.nan = no Basement so np.nan → None)
df['TotalBsmtSF'] = df['TotalBsmtSF'].fillna(0)
df['BsmtFinSF1'] = df['BsmtFinSF1'].fillna(0)
df['BsmtFinSF2'] = df['BsmtFinSF2'].fillna(0)
df['BsmtUnfSF'] = df['BsmtUnfSF'].fillna(0)
df['BsmtHalfBath'] = df['BsmtHalfBath'].fillna(0)
df['BsmtFullBath'] = df['BsmtFullBath'].fillna(0)

# LotFrontage: Missing values must be imputed; as there is no other obvious way, the value can be imputed by linear regression
tsvd = TruncatedSVD(n_components=10)
imputation_pipeline = Pipeline([('encoder',OneHotEncoder(handle_unknown='ignore')),
                               ('tsvd',tsvd),
                               ('linreg',LinearRegression())])

X_imp_train = df.loc[df['LotFrontage'].notnull()].drop(['SalePrice','LotFrontage'],axis=1)
y_imp_train = df.loc[:,'LotFrontage'].dropna()
X_imp = df.loc[df['LotFrontage'].isnull()].drop(['SalePrice','LotFrontage'],axis=1)

imputation_pipeline.fit(X_imp_train,y_imp_train)
imp_values = imputation_pipeline.predict(X_imp)

index_list = df.loc[df['LotFrontage'].isnull()].index.tolist()
imp_Series = pd.Series(imp_values,index=index_list)
df['LotFrontage'] = df['LotFrontage'].fillna(imp_Series)

assert df.drop('SalePrice',axis=1).isnull().sum().sum() == 0

# %%
#Add information: Houses with same YearRemodAdd and YearBuilt have no Remod Added

df.loc[df['YearRemodAdd']==df['YearBuilt'],'YearRemodAdd'] = 'None'

# %%
# Converting numerical features to objects: Nominal features
to_be_converted = ['MoSold','YrSold','YearBuilt','YearRemodAdd','GarageYrBlt','MSSubClass']

for feature in to_be_converted:
    df[feature].astype(object)

# %%
# Convert numerical features to objects/categories: Ordinal Features
to_be_converted_ordinal = ['MSZoning','Alley','MasVnrType','ExterQual','FireplaceQu','BsmtQual','BsmtCond','HeatingQC','KitchenQual',
                           'GarageQual','GarageCond','PoolQC','Utilities','BldgType','OverallQual','OverallCond','ExterCond','BsmtExposure',
                           'BsmtFinType1','BsmtFinType2','Functional','GarageFinish','PavedDrive','Fence']

for feature in to_be_converted_ordinal:
    le = LabelEncoder()
    encoded_feature = le.fit_transform(df[feature])
    df[feature] = encoded_feature

# %%
# Shift numerical features' distribution towards normal distribution by running a boxcox transformation over all remaining numerical features
# For easier interpretability, use simple log transformation for target variable 

num_features = [feature for feature in df.columns if df[feature].dtype != 'object']
for feature in num_features:
    if feature != 'SalePrice':
        transform_data = df[feature].loc[df[feature]>0]
        lm = 0.15
        transform_result = stats.boxcox(transform_data,lm)
        transform_impose = np.empty_like(df[feature])
        transform_impose[df[feature] > 0] = transform_result
        transform_impose[df[feature]<= 0] = df[feature].loc[df[feature]<=0]
        df[feature] = transform_impose
    else:
        df[feature] = df[feature].transform(lambda x: np.log(x))

# %%
# Get dummies from dataset
df_processed = pd.get_dummies(df)

# %%
# Data Wrangling is concluded
train_processed = df_processed.loc[df_processed['SalePrice'].notnull()]
test_processed = df_processed.loc[df_processed['SalePrice'].isnull()]
assert train_processed.isnull().sum().sum() == 0
assert test_processed.isnull().sum().sum() == test_processed.shape[0]
assert train_processed.shape[1] == test_processed.shape[1]
assert test_processed.shape[0] == df_test.shape[0]
train_processed.to_csv('train_processed.csv',index_label='Id')
test_processed.drop('SalePrice',axis=1).to_csv('test_processed.csv',index_label='Id')

# %% [markdown]
# ## Modelling

# %%
# Implementing RMSLE function
def rmsle(labels,predictions,exponential_transformation=True):
    if exponential_transformation:
        labels = np.exp(labels)
        predictions = np.exp(predictions)
    root_mean_squared_error = np.mean((np.log(labels)-np.log(predictions))**2)**0.5

    return root_mean_squared_error

# %%
# Load processed training data
train_data = pd.read_csv('train_processed.csv',index_col='Id')

# %%
# Prepare the data
X = train_data.drop('SalePrice',axis=1)
y_train = np.array(train_data.loc[:,'SalePrice'])

# %%
# Data preparation
preparation_pipeline = make_pipeline(StandardScaler())
print(X.shape)
X_train = preparation_pipeline.fit_transform(X)
# Out:
# (1460, 273)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
# Prepare KFold validation function
def rmsle_cv(model):
    kf = KFold(3,shuffle=True,random_state=42).get_n_splits(X_train)
    rmse = np.sqrt(-cross_val_score(model,X_train,y_train,scoring='neg_mean_squared_error',cv=kf))
    return rmse

# %%
# Define model test function
# TODO: Implement GridSearchCV or RandomizedGridSearchCV
def model_testing(model):
    rmsle_train_score = rmsle_cv(model)
    model.fit(X_train,y_train)
    
    return rmsle_train_score

# %%
# Train Base Models
lin_reg = LinearRegression()
rand_for = RandomForestRegressor()
sup_vec_reg = SVR()
ada_boost = AdaBoostRegressor()
grad_boost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                       max_depth=4, max_features='sqrt',
                                       min_samples_leaf=15, min_samples_split=10, 
                                       loss='huber', random_state =5)
xgboost_reg = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                               learning_rate=0.05, max_depth=3, 
                               min_child_weight=1.7817, n_estimators=2200,
                               reg_alpha=0.4640, reg_lambda=0.8571,
                               subsample=0.5213, silent=1,
                               random_state =7, nthread = -1)

models= [lin_reg,rand_for,sup_vec_reg,ada_boost,grad_boost,xgboost_reg]
names = ['LR','RF','SVR','ABR','GBR','XGB-Test']

train_results = list(map(model_testing,models))
# Out:
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
# Training Results
rmsle_train_scores = [train_results[i] for i in range(len(train_results))]

# %%
# Plotting Training Results
train_results_df = pd.DataFrame(rmsle_train_scores,columns=['CV'+str(i+1) for i in range(rmsle_train_scores[0].shape[0])])
train_results_df['Model'] = names
train_results_df1 = train_results_df.melt(id_vars='Model',var_name='Validation',value_name='RMSLE-Score')
sns.barplot(x='Model',y='RMSLE-Score',data=train_results_df1,hue='Validation').set_title('Training RMSLEs')
plt.ylim(0,0.5)

plt.show()
print(train_results_df)
# Out:
#             CV1           CV2           CV3     Model
# 0  4.822735e+12  1.145681e+12  4.705142e+12        LR
# 1  1.628904e-01  1.791713e-01  1.654528e-01        RF
# 2  2.027278e-01  2.100570e-01  1.828635e-01       SVR
# 3  1.779724e-01  1.917669e-01  1.792611e-01       ABR
# 4  1.262178e-01  1.441896e-01  1.301842e-01       GBR
# 5  1.287675e-01  1.471164e-01  1.320074e-01  XGB-Test

# %%
# Train a UL model on the data (for testing purposes of the meta model)
# Model: Gaussian Mixture Model, testing for optimal k
from sklearn.mixture import GaussianMixture

# %%
# Define Testing function
def gmm_test(data,max_components):
    total_score = []
    test_components = []
    for i in range(max_components):
        model = GaussianMixture(n_components=i+1)
        labels = model.fit_predict(data)
        score = model.aic(data)
        total_score.append(score)
        test_components.append(i+1)
    sns.lineplot(x=test_components,y=total_score)
    plt.xticks(list(range(1,31)))
    plt.show()

# %%
# Testing for the optimal model
gmm_test(X_train,30)

# %%
# It appears, that the optimal model, according to the AIC, is one with n_components = 22
gm_model = GaussianMixture(n_components = 22)
label_predictions = gm_model.fit_predict(X_train)
if gm_model not in models:
    models.append(gm_model)

# %%
# Combine predictions and labels
lin_reg_pred = lin_reg.predict(X_train)
rand_for_pred = rand_for.predict(X_train)
sup_vec_reg_pred = sup_vec_reg.predict(X_train)
ada_boost_pred = ada_boost.predict(X_train)
grad_boost_pred = grad_boost.predict(X_train)
xgboost_reg_pred = xgboost_reg.predict(X_train)

meta_data_train = np.column_stack((lin_reg_pred,rand_for_pred,sup_vec_reg_pred,ada_boost_pred,grad_boost_pred,xgboost_reg_pred,label_predictions))

# %%
# Train Meta model (keras DLN)
from keras.models import Sequential
from keras.layers import Dropout, Dense, LeakyReLU

meta_model_dnn = Sequential()
meta_model_dnn.add(Dense(256,kernel_initializer='normal',input_dim=meta_data_train.shape[1]))
meta_model_dnn.add(Dropout(rate=0.2))
meta_model_dnn.add(LeakyReLU())

for i in range(100):
    meta_model_dnn.add(Dense(128,kernel_initializer='normal'))
    meta_model_dnn.add(Dropout(rate=0.2))
    meta_model_dnn.add(LeakyReLU())

meta_model_dnn.add(Dense(1,kernel_initializer='normal',activation='linear'))

meta_model_dnn.compile(optimizer='SGD',loss='mean_squared_error',metrics=['mean_squared_error'])

meta_model_dnn.summary()
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_36 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_39 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_41 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_45 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_46 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_47 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_48 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_49 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_50 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_51 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_52 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_52 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_53 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_53 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_54 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_54 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_55 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_55 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_56 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_56 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_57 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_57 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_58 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_58 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_59 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_59 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_60 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_60 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_61 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_61 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_62 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_62 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_63 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_63 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_64 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_64 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_65 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_65 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_66 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_66 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_67 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_68 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_69 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_69 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_70 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_70 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_71 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_71 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_72 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_72 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_73 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_73 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_74 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_74 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_75 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_75 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_75 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_76 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_76 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_76 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_77 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_77 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_77 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_78 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_78 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_78 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_79 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_79 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_79 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_80 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_80 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_81 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_81 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_82 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_82 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_83 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_83 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_83 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_84 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_84 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_84 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_85 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_85 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_85 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_86 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_86 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_86 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_87 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_87 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_87 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_88 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_88 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_88 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_89 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_89 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_89 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_90 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_90 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_90 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_91 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_91 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_91 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_92 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_92 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_92 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_93 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_93 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_93 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_94 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_94 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_94 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_95 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_95 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_95 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_96 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_96 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_96 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_97 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_97 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_97 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_98 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_98 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_98 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_99 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_99 (Dropout)         (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_99 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_100 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dropout_100 (Dropout)        (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_100 (LeakyReLU)  (None, 128)               0
# _________________________________________________________________
# dense_101 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dropout_101 (Dropout)        (None, 128)               0
# _________________________________________________________________
# leaky_re_lu_101 (LeakyReLU)  (None, 128)               0
# _________________________________________________________________
# dense_102 (Dense)            (None, 1)                 129
# =================================================================
# Total params: 1,669,761
# Trainable params: 1,669,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train Meta Model
meta_model_dnn.fit(meta_data_train,y_train,epochs=500,batch_size=32,shuffle=True,validation_split=0.1,verbose=1)
# Out:
# WARNING:tensorflow:From C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1314 samples, validate on 146 samples
# Epoch 1/500
# 1314/1314 [==============================] - 17s 13ms/step - loss: 32.2828 - mean_squared_error: 32.2828 - val_loss: 1.6769 - val_mean_squared_error: 1.6769
# Epoch 2/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 1.2033 - mean_squared_error: 1.2033 - val_loss: 0.5793 - val_mean_squared_error: 0.5793
# Epoch 3/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.9710 - mean_squared_error: 0.9710 - val_loss: 0.6002 - val_mean_squared_error: 0.6002
# Epoch 4/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.8218 - mean_squared_error: 0.8218 - val_loss: 0.6092 - val_mean_squared_error: 0.6092
# Epoch 5/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.8223 - mean_squared_error: 0.8223 - val_loss: 0.4924 - val_mean_squared_error: 0.4924
# Epoch 6/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.7900 - mean_squared_error: 0.7900 - val_loss: 1.3190 - val_mean_squared_error: 1.3190
# Epoch 7/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.7470 - mean_squared_error: 0.7470 - val_loss: 0.1903 - val_mean_squared_error: 0.1903
# Epoch 8/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.6632 - mean_squared_error: 0.6632 - val_loss: 0.1634 - val_mean_squared_error: 0.1634
# Epoch 9/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.6812 - mean_squared_error: 0.6812 - val_loss: 0.2183 - val_mean_squared_error: 0.2183
# Epoch 10/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.6227 - mean_squared_error: 0.6227 - val_loss: 2.0503 - val_mean_squared_error: 2.0503
# Epoch 11/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.6826 - mean_squared_error: 0.6826 - val_loss: 0.2380 - val_mean_squared_error: 0.2380
# Epoch 12/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.6217 - mean_squared_error: 0.6217 - val_loss: 0.2400 - val_mean_squared_error: 0.2400
# Epoch 13/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5583 - mean_squared_error: 0.5583 - val_loss: 0.2067 - val_mean_squared_error: 0.2067
# Epoch 14/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5732 - mean_squared_error: 0.5732 - val_loss: 0.1666 - val_mean_squared_error: 0.1666
# Epoch 15/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5245 - mean_squared_error: 0.5245 - val_loss: 0.1734 - val_mean_squared_error: 0.1734
# Epoch 16/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5660 - mean_squared_error: 0.5660 - val_loss: 0.1696 - val_mean_squared_error: 0.1696
# Epoch 17/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5400 - mean_squared_error: 0.5400 - val_loss: 0.1696 - val_mean_squared_error: 0.1696
# Epoch 18/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5045 - mean_squared_error: 0.5045 - val_loss: 0.1923 - val_mean_squared_error: 0.1923
# Epoch 19/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5175 - mean_squared_error: 0.5175 - val_loss: 0.3507 - val_mean_squared_error: 0.3507
# Epoch 20/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5021 - mean_squared_error: 0.5021 - val_loss: 0.2768 - val_mean_squared_error: 0.2768
# Epoch 21/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4863 - mean_squared_error: 0.4863 - val_loss: 0.6389 - val_mean_squared_error: 0.6389
# Epoch 22/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.5133 - mean_squared_error: 0.5133 - val_loss: 0.3014 - val_mean_squared_error: 0.3014
# Epoch 23/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4788 - mean_squared_error: 0.4788 - val_loss: 0.3258 - val_mean_squared_error: 0.3258
# Epoch 24/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4956 - mean_squared_error: 0.4956 - val_loss: 0.1644 - val_mean_squared_error: 0.1644
# Epoch 25/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4600 - mean_squared_error: 0.4600 - val_loss: 0.2226 - val_mean_squared_error: 0.2226
# Epoch 26/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4514 - mean_squared_error: 0.4514 - val_loss: 0.2250 - val_mean_squared_error: 0.2250
# Epoch 27/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4421 - mean_squared_error: 0.4421 - val_loss: 0.1623 - val_mean_squared_error: 0.1623
# Epoch 28/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4481 - mean_squared_error: 0.4481 - val_loss: 0.3339 - val_mean_squared_error: 0.3339
# Epoch 29/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4502 - mean_squared_error: 0.4502 - val_loss: 0.4185 - val_mean_squared_error: 0.4185
# Epoch 30/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4369 - mean_squared_error: 0.4369 - val_loss: 0.1973 - val_mean_squared_error: 0.1973
# Epoch 31/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.4385 - mean_squared_error: 0.4385 - val_loss: 0.2627 - val_mean_squared_error: 0.2627
# Epoch 32/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4455 - mean_squared_error: 0.4455 - val_loss: 0.2635 - val_mean_squared_error: 0.2635
# Epoch 33/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4340 - mean_squared_error: 0.4340 - val_loss: 0.2083 - val_mean_squared_error: 0.2083
# Epoch 34/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4243 - mean_squared_error: 0.4243 - val_loss: 0.3486 - val_mean_squared_error: 0.3486
# Epoch 35/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4023 - mean_squared_error: 0.4023 - val_loss: 0.2711 - val_mean_squared_error: 0.2711
# Epoch 36/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4232 - mean_squared_error: 0.4232 - val_loss: 0.1921 - val_mean_squared_error: 0.1921
# Epoch 37/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4178 - mean_squared_error: 0.4178 - val_loss: 0.2542 - val_mean_squared_error: 0.2542
# Epoch 38/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3903 - mean_squared_error: 0.3903 - val_loss: 0.1948 - val_mean_squared_error: 0.1948
# Epoch 39/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4041 - mean_squared_error: 0.4041 - val_loss: 0.1652 - val_mean_squared_error: 0.1652
# Epoch 40/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4071 - mean_squared_error: 0.4071 - val_loss: 0.3272 - val_mean_squared_error: 0.3272
# Epoch 41/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.4071 - mean_squared_error: 0.4071 - val_loss: 0.1769 - val_mean_squared_error: 0.1769
# Epoch 42/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3916 - mean_squared_error: 0.3916 - val_loss: 0.1887 - val_mean_squared_error: 0.1887
# Epoch 43/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.4098 - mean_squared_error: 0.4098 - val_loss: 0.1799 - val_mean_squared_error: 0.1799
# Epoch 44/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3898 - mean_squared_error: 0.3898 - val_loss: 0.1725 - val_mean_squared_error: 0.1725
# Epoch 45/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3865 - mean_squared_error: 0.3865 - val_loss: 0.1818 - val_mean_squared_error: 0.1818
# Epoch 46/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3805 - mean_squared_error: 0.3805 - val_loss: 0.2284 - val_mean_squared_error: 0.2284
# Epoch 47/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3864 - mean_squared_error: 0.3864 - val_loss: 0.1780 - val_mean_squared_error: 0.1780
# Epoch 48/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3844 - mean_squared_error: 0.3844 - val_loss: 0.1680 - val_mean_squared_error: 0.1680
# Epoch 49/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3784 - mean_squared_error: 0.3784 - val_loss: 0.2252 - val_mean_squared_error: 0.2252
# Epoch 50/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3721 - mean_squared_error: 0.3721 - val_loss: 0.1713 - val_mean_squared_error: 0.1713
# Epoch 51/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3790 - mean_squared_error: 0.3790 - val_loss: 0.1618 - val_mean_squared_error: 0.1618
# Epoch 52/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3588 - mean_squared_error: 0.3588 - val_loss: 0.1956 - val_mean_squared_error: 0.1956
# Epoch 53/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3700 - mean_squared_error: 0.3700 - val_loss: 0.1638 - val_mean_squared_error: 0.1638
# Epoch 54/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3461 - mean_squared_error: 0.3461 - val_loss: 0.1715 - val_mean_squared_error: 0.1715
# Epoch 55/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3477 - mean_squared_error: 0.3477 - val_loss: 0.2946 - val_mean_squared_error: 0.2946
# Epoch 56/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3892 - mean_squared_error: 0.3892 - val_loss: 0.1680 - val_mean_squared_error: 0.1680
# Epoch 57/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3533 - mean_squared_error: 0.3533 - val_loss: 0.1630 - val_mean_squared_error: 0.1630
# Epoch 58/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3564 - mean_squared_error: 0.3564 - val_loss: 0.1960 - val_mean_squared_error: 0.1960
# Epoch 59/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3428 - mean_squared_error: 0.3428 - val_loss: 0.2838 - val_mean_squared_error: 0.2838
# Epoch 60/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3461 - mean_squared_error: 0.3461 - val_loss: 0.1992 - val_mean_squared_error: 0.1992
# Epoch 61/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3446 - mean_squared_error: 0.3446 - val_loss: 0.2968 - val_mean_squared_error: 0.2968
# Epoch 62/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3480 - mean_squared_error: 0.3480 - val_loss: 0.1906 - val_mean_squared_error: 0.1906
# Epoch 63/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3345 - mean_squared_error: 0.3345 - val_loss: 0.1754 - val_mean_squared_error: 0.1754
# Epoch 64/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3365 - mean_squared_error: 0.3365 - val_loss: 0.1757 - val_mean_squared_error: 0.1757
# Epoch 65/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3204 - mean_squared_error: 0.3204 - val_loss: 0.1876 - val_mean_squared_error: 0.1876
# Epoch 66/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3147 - mean_squared_error: 0.3147 - val_loss: 0.2263 - val_mean_squared_error: 0.2263
# Epoch 67/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3290 - mean_squared_error: 0.3290 - val_loss: 0.1705 - val_mean_squared_error: 0.1705
# Epoch 68/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3297 - mean_squared_error: 0.3297 - val_loss: 0.1644 - val_mean_squared_error: 0.1644
# Epoch 69/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3144 - mean_squared_error: 0.3144 - val_loss: 0.1619 - val_mean_squared_error: 0.1619
# Epoch 70/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3254 - mean_squared_error: 0.3254 - val_loss: 0.2027 - val_mean_squared_error: 0.2027
# Epoch 71/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3049 - mean_squared_error: 0.3049 - val_loss: 0.2292 - val_mean_squared_error: 0.2292
# Epoch 72/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3180 - mean_squared_error: 0.3180 - val_loss: 0.1896 - val_mean_squared_error: 0.1896
# Epoch 73/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3152 - mean_squared_error: 0.3152 - val_loss: 0.1785 - val_mean_squared_error: 0.1785
# Epoch 74/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3153 - mean_squared_error: 0.3153 - val_loss: 0.1751 - val_mean_squared_error: 0.1751
# Epoch 75/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3172 - mean_squared_error: 0.3172 - val_loss: 0.1642 - val_mean_squared_error: 0.1642
# Epoch 76/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3276 - mean_squared_error: 0.3276 - val_loss: 0.1956 - val_mean_squared_error: 0.1956
# Epoch 77/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3178 - mean_squared_error: 0.3178 - val_loss: 0.1719 - val_mean_squared_error: 0.1719
# Epoch 78/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3316 - mean_squared_error: 0.3316 - val_loss: 0.3466 - val_mean_squared_error: 0.3466
# Epoch 79/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.3180 - mean_squared_error: 0.3180 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 80/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2961 - mean_squared_error: 0.2961 - val_loss: 0.1641 - val_mean_squared_error: 0.1641
# Epoch 81/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3248 - mean_squared_error: 0.3248 - val_loss: 0.1725 - val_mean_squared_error: 0.1725
# Epoch 82/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2997 - mean_squared_error: 0.2997 - val_loss: 0.1820 - val_mean_squared_error: 0.1820
# Epoch 83/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3016 - mean_squared_error: 0.3016 - val_loss: 0.1751 - val_mean_squared_error: 0.1751
# Epoch 84/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2980 - mean_squared_error: 0.2980 - val_loss: 0.1918 - val_mean_squared_error: 0.1918
# Epoch 85/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3050 - mean_squared_error: 0.3050 - val_loss: 0.1783 - val_mean_squared_error: 0.1783
# Epoch 86/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3067 - mean_squared_error: 0.3067 - val_loss: 0.1720 - val_mean_squared_error: 0.1720
# Epoch 87/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2884 - mean_squared_error: 0.2884 - val_loss: 0.1862 - val_mean_squared_error: 0.1862
# Epoch 88/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3042 - mean_squared_error: 0.3042 - val_loss: 0.1906 - val_mean_squared_error: 0.1906
# Epoch 89/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2964 - mean_squared_error: 0.2964 - val_loss: 0.1713 - val_mean_squared_error: 0.1713
# Epoch 90/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2881 - mean_squared_error: 0.2881 - val_loss: 0.2393 - val_mean_squared_error: 0.2393
# Epoch 91/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2876 - mean_squared_error: 0.2876 - val_loss: 0.1622 - val_mean_squared_error: 0.1622
# Epoch 92/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2903 - mean_squared_error: 0.2903 - val_loss: 0.1742 - val_mean_squared_error: 0.1742
# Epoch 93/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3013 - mean_squared_error: 0.3013 - val_loss: 0.1796 - val_mean_squared_error: 0.1796
# Epoch 94/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2809 - mean_squared_error: 0.2809 - val_loss: 0.2378 - val_mean_squared_error: 0.2378
# Epoch 95/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3009 - mean_squared_error: 0.3009 - val_loss: 0.1937 - val_mean_squared_error: 0.1937
# Epoch 96/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2825 - mean_squared_error: 0.2825 - val_loss: 0.1679 - val_mean_squared_error: 0.1679
# Epoch 97/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2840 - mean_squared_error: 0.2840 - val_loss: 0.2299 - val_mean_squared_error: 0.2299
# Epoch 98/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.3134 - mean_squared_error: 0.3134 - val_loss: 0.1714 - val_mean_squared_error: 0.1714
# Epoch 99/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2830 - mean_squared_error: 0.2830 - val_loss: 0.2950 - val_mean_squared_error: 0.2950
# Epoch 100/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2769 - mean_squared_error: 0.2769 - val_loss: 0.1960 - val_mean_squared_error: 0.1960
# Epoch 101/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2807 - mean_squared_error: 0.2807 - val_loss: 0.1631 - val_mean_squared_error: 0.1631
# Epoch 102/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2768 - mean_squared_error: 0.2768 - val_loss: 0.1646 - val_mean_squared_error: 0.1646
# Epoch 103/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2836 - mean_squared_error: 0.2836 - val_loss: 0.1783 - val_mean_squared_error: 0.1783
# Epoch 104/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2883 - mean_squared_error: 0.2883 - val_loss: 0.1684 - val_mean_squared_error: 0.1684
# Epoch 105/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2974 - mean_squared_error: 0.2974 - val_loss: 0.1811 - val_mean_squared_error: 0.1811
# Epoch 106/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2846 - mean_squared_error: 0.2846 - val_loss: 0.2027 - val_mean_squared_error: 0.2027
# Epoch 107/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2841 - mean_squared_error: 0.2841 - val_loss: 0.1665 - val_mean_squared_error: 0.1665
# Epoch 108/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2761 - mean_squared_error: 0.2761 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 109/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2717 - mean_squared_error: 0.2717 - val_loss: 0.1798 - val_mean_squared_error: 0.1798
# Epoch 110/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2720 - mean_squared_error: 0.2720 - val_loss: 0.2677 - val_mean_squared_error: 0.2677
# Epoch 111/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2667 - mean_squared_error: 0.2667 - val_loss: 0.1950 - val_mean_squared_error: 0.1950
# Epoch 112/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2789 - mean_squared_error: 0.2789 - val_loss: 0.1983 - val_mean_squared_error: 0.1983
# Epoch 113/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2752 - mean_squared_error: 0.2752 - val_loss: 0.1788 - val_mean_squared_error: 0.1788
# Epoch 114/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2709 - mean_squared_error: 0.2709 - val_loss: 0.1775 - val_mean_squared_error: 0.1775
# Epoch 115/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2391 - mean_squared_error: 0.2391 - val_loss: 0.1664 - val_mean_squared_error: 0.1664
# Epoch 116/500
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.2659 - mean_squared_error: 0.2659 - val_loss: 0.1710 - val_mean_squared_error: 0.1710
# Epoch 117/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2543 - mean_squared_error: 0.2543 - val_loss: 0.1618 - val_mean_squared_error: 0.1618
# Epoch 118/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2605 - mean_squared_error: 0.2605 - val_loss: 0.1655 - val_mean_squared_error: 0.1655
# Epoch 119/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2694 - mean_squared_error: 0.2694 - val_loss: 0.2391 - val_mean_squared_error: 0.2391
# Epoch 120/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2576 - mean_squared_error: 0.2576 - val_loss: 0.1627 - val_mean_squared_error: 0.1627
# Epoch 121/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2412 - mean_squared_error: 0.2412 - val_loss: 0.1640 - val_mean_squared_error: 0.1640
# Epoch 122/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2540 - mean_squared_error: 0.2540 - val_loss: 0.1717 - val_mean_squared_error: 0.1717
# Epoch 123/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2749 - mean_squared_error: 0.2749 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 124/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2731 - mean_squared_error: 0.2731 - val_loss: 0.1627 - val_mean_squared_error: 0.1627
# Epoch 125/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2623 - mean_squared_error: 0.2623 - val_loss: 0.1624 - val_mean_squared_error: 0.1624
# Epoch 126/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2781 - mean_squared_error: 0.2781 - val_loss: 0.2502 - val_mean_squared_error: 0.2502
# Epoch 127/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2661 - mean_squared_error: 0.2661 - val_loss: 0.2776 - val_mean_squared_error: 0.2776
# Epoch 128/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2722 - mean_squared_error: 0.2722 - val_loss: 0.1732 - val_mean_squared_error: 0.1732
# Epoch 129/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2601 - mean_squared_error: 0.2601 - val_loss: 0.1756 - val_mean_squared_error: 0.1756
# Epoch 130/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2623 - mean_squared_error: 0.2623 - val_loss: 0.1866 - val_mean_squared_error: 0.1866
# Epoch 131/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2584 - mean_squared_error: 0.2584 - val_loss: 0.1748 - val_mean_squared_error: 0.1748
# Epoch 132/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2438 - mean_squared_error: 0.2438 - val_loss: 0.1636 - val_mean_squared_error: 0.1636
# Epoch 133/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2540 - mean_squared_error: 0.2540 - val_loss: 0.1789 - val_mean_squared_error: 0.1789
# Epoch 134/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2449 - mean_squared_error: 0.2449 - val_loss: 0.2075 - val_mean_squared_error: 0.2075
# Epoch 135/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2533 - mean_squared_error: 0.2533 - val_loss: 0.1893 - val_mean_squared_error: 0.1893
# Epoch 136/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2563 - mean_squared_error: 0.2563 - val_loss: 0.1839 - val_mean_squared_error: 0.1839
# Epoch 137/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2522 - mean_squared_error: 0.2522 - val_loss: 0.1948 - val_mean_squared_error: 0.1948
# Epoch 138/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2510 - mean_squared_error: 0.2510 - val_loss: 0.1709 - val_mean_squared_error: 0.1709
# Epoch 139/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2395 - mean_squared_error: 0.2395 - val_loss: 0.2002 - val_mean_squared_error: 0.2002
# Epoch 140/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2434 - mean_squared_error: 0.2434 - val_loss: 0.1720 - val_mean_squared_error: 0.1720
# Epoch 141/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2505 - mean_squared_error: 0.2505 - val_loss: 0.1638 - val_mean_squared_error: 0.1638
# Epoch 142/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2492 - mean_squared_error: 0.2492 - val_loss: 0.1665 - val_mean_squared_error: 0.1665
# Epoch 143/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2587 - mean_squared_error: 0.2587 - val_loss: 0.1648 - val_mean_squared_error: 0.1648
# Epoch 144/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2488 - mean_squared_error: 0.2488 - val_loss: 0.1783 - val_mean_squared_error: 0.1783
# Epoch 145/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2571 - mean_squared_error: 0.2571 - val_loss: 0.1669 - val_mean_squared_error: 0.1669
# Epoch 146/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2352 - mean_squared_error: 0.2352 - val_loss: 0.1693 - val_mean_squared_error: 0.1693
# Epoch 147/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2499 - mean_squared_error: 0.2499 - val_loss: 0.1676 - val_mean_squared_error: 0.1676
# Epoch 148/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2557 - mean_squared_error: 0.2557 - val_loss: 0.1682 - val_mean_squared_error: 0.1682
# Epoch 149/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2530 - mean_squared_error: 0.2530 - val_loss: 0.1660 - val_mean_squared_error: 0.1660
# Epoch 150/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2442 - mean_squared_error: 0.2442 - val_loss: 0.1693 - val_mean_squared_error: 0.1693
# Epoch 151/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2466 - mean_squared_error: 0.2466 - val_loss: 0.1651 - val_mean_squared_error: 0.1651
# Epoch 152/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2375 - mean_squared_error: 0.2375 - val_loss: 0.1655 - val_mean_squared_error: 0.1655
# Epoch 153/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2352 - mean_squared_error: 0.2352 - val_loss: 0.2381 - val_mean_squared_error: 0.2381
# Epoch 154/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2556 - mean_squared_error: 0.2556 - val_loss: 0.1798 - val_mean_squared_error: 0.1798
# Epoch 155/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2617 - mean_squared_error: 0.2617 - val_loss: 0.2042 - val_mean_squared_error: 0.2042
# Epoch 156/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2458 - mean_squared_error: 0.2458 - val_loss: 0.1855 - val_mean_squared_error: 0.1855
# Epoch 157/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2399 - mean_squared_error: 0.2399 - val_loss: 0.1644 - val_mean_squared_error: 0.1644
# Epoch 158/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2476 - mean_squared_error: 0.2476 - val_loss: 0.1806 - val_mean_squared_error: 0.1806
# Epoch 159/500
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.2401 - mean_squared_error: 0.2401 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 160/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2348 - mean_squared_error: 0.2348 - val_loss: 0.1649 - val_mean_squared_error: 0.1649
# Epoch 161/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2523 - mean_squared_error: 0.2523 - val_loss: 0.1653 - val_mean_squared_error: 0.1653
# Epoch 162/500
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.2403 - mean_squared_error: 0.2403 - val_loss: 0.1618 - val_mean_squared_error: 0.1618
# Epoch 163/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2384 - mean_squared_error: 0.2384 - val_loss: 0.1770 - val_mean_squared_error: 0.1770
# Epoch 164/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2309 - mean_squared_error: 0.2309 - val_loss: 0.1896 - val_mean_squared_error: 0.1896
# Epoch 165/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2440 - mean_squared_error: 0.2440 - val_loss: 0.3037 - val_mean_squared_error: 0.3037
# Epoch 166/500
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.2438 - mean_squared_error: 0.2438 - val_loss: 0.1629 - val_mean_squared_error: 0.1629
# Epoch 167/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2274 - mean_squared_error: 0.2274 - val_loss: 0.2049 - val_mean_squared_error: 0.2049
# Epoch 168/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2446 - mean_squared_error: 0.2446 - val_loss: 0.1674 - val_mean_squared_error: 0.1674
# Epoch 169/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2399 - mean_squared_error: 0.2399 - val_loss: 0.1940 - val_mean_squared_error: 0.1940
# Epoch 170/500
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.2407 - mean_squared_error: 0.2407 - val_loss: 0.2232 - val_mean_squared_error: 0.2232
# Epoch 171/500
# 1314/1314 [==============================] - 5s 4ms/step - loss: 0.2418 - mean_squared_error: 0.2418 - val_loss: 0.1687 - val_mean_squared_error: 0.1687
# Epoch 172/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2432 - mean_squared_error: 0.2432 - val_loss: 0.1623 - val_mean_squared_error: 0.1623
# Epoch 173/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2264 - mean_squared_error: 0.2264 - val_loss: 0.1718 - val_mean_squared_error: 0.1718
# Epoch 174/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2206 - mean_squared_error: 0.2206 - val_loss: 0.2031 - val_mean_squared_error: 0.2031
# Epoch 175/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2316 - mean_squared_error: 0.2316 - val_loss: 0.1733 - val_mean_squared_error: 0.1733
# Epoch 176/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2312 - mean_squared_error: 0.2312 - val_loss: 0.2253 - val_mean_squared_error: 0.2253
# Epoch 177/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2309 - mean_squared_error: 0.2309 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 178/500
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.2436 - mean_squared_error: 0.2436 - val_loss: 0.1623 - val_mean_squared_error: 0.1623
# Epoch 179/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2464 - mean_squared_error: 0.2464 - val_loss: 0.2072 - val_mean_squared_error: 0.2072
# Epoch 180/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2408 - mean_squared_error: 0.2408 - val_loss: 0.1761 - val_mean_squared_error: 0.1761
# Epoch 181/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2335 - mean_squared_error: 0.2335 - val_loss: 0.2583 - val_mean_squared_error: 0.2583
# Epoch 182/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2425 - mean_squared_error: 0.2425 - val_loss: 0.1831 - val_mean_squared_error: 0.1831
# Epoch 183/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2112 - mean_squared_error: 0.2112 - val_loss: 0.2061 - val_mean_squared_error: 0.2061
# Epoch 184/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2334 - mean_squared_error: 0.2334 - val_loss: 0.1834 - val_mean_squared_error: 0.1834
# Epoch 185/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2211 - mean_squared_error: 0.2211 - val_loss: 0.1726 - val_mean_squared_error: 0.1726
# Epoch 186/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2252 - mean_squared_error: 0.2252 - val_loss: 0.1673 - val_mean_squared_error: 0.1673
# Epoch 187/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2330 - mean_squared_error: 0.2330 - val_loss: 0.1634 - val_mean_squared_error: 0.1634
# Epoch 188/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2253 - mean_squared_error: 0.2253 - val_loss: 0.1912 - val_mean_squared_error: 0.1912
# Epoch 189/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2349 - mean_squared_error: 0.2349 - val_loss: 0.1808 - val_mean_squared_error: 0.1808
# Epoch 190/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2295 - mean_squared_error: 0.2295 - val_loss: 0.1737 - val_mean_squared_error: 0.1737
# Epoch 191/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2315 - mean_squared_error: 0.2315 - val_loss: 0.1679 - val_mean_squared_error: 0.1679
# Epoch 192/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2310 - mean_squared_error: 0.2310 - val_loss: 0.1859 - val_mean_squared_error: 0.1859
# Epoch 193/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2285 - mean_squared_error: 0.2285 - val_loss: 0.1717 - val_mean_squared_error: 0.1717
# Epoch 194/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2144 - mean_squared_error: 0.2144 - val_loss: 0.1723 - val_mean_squared_error: 0.1723
# Epoch 195/500
# 1314/1314 [==============================] - 4s 3ms/step - loss: 0.2279 - mean_squared_error: 0.2279 - val_loss: 0.1738 - val_mean_squared_error: 0.1738
# Epoch 196/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2245 - mean_squared_error: 0.2245 - val_loss: 0.2158 - val_mean_squared_error: 0.2158
# Epoch 197/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2422 - mean_squared_error: 0.2422 - val_loss: 0.1763 - val_mean_squared_error: 0.1763
# Epoch 198/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2318 - mean_squared_error: 0.2318 - val_loss: 0.1625 - val_mean_squared_error: 0.1625
# Epoch 199/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2294 - mean_squared_error: 0.2294 - val_loss: 0.2093 - val_mean_squared_error: 0.2093
# Epoch 200/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2246 - mean_squared_error: 0.2246 - val_loss: 0.1792 - val_mean_squared_error: 0.1792
# Epoch 201/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2143 - mean_squared_error: 0.2143 - val_loss: 0.1660 - val_mean_squared_error: 0.1660
# Epoch 202/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2134 - mean_squared_error: 0.2134 - val_loss: 0.1945 - val_mean_squared_error: 0.1945
# Epoch 203/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2215 - mean_squared_error: 0.2215 - val_loss: 0.1632 - val_mean_squared_error: 0.1632
# Epoch 204/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2250 - mean_squared_error: 0.2250 - val_loss: 0.2536 - val_mean_squared_error: 0.2536
# Epoch 205/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2243 - mean_squared_error: 0.2243 - val_loss: 0.1667 - val_mean_squared_error: 0.1667
# Epoch 206/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2223 - mean_squared_error: 0.2223 - val_loss: 0.1630 - val_mean_squared_error: 0.1630
# Epoch 207/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2263 - mean_squared_error: 0.2263 - val_loss: 0.1626 - val_mean_squared_error: 0.1626
# Epoch 208/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2152 - mean_squared_error: 0.2152 - val_loss: 0.1769 - val_mean_squared_error: 0.1769
# Epoch 209/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2307 - mean_squared_error: 0.2307 - val_loss: 0.1715 - val_mean_squared_error: 0.1715
# Epoch 210/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2226 - mean_squared_error: 0.2226 - val_loss: 0.1624 - val_mean_squared_error: 0.1624
# Epoch 211/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2211 - mean_squared_error: 0.2211 - val_loss: 0.1632 - val_mean_squared_error: 0.1632
# Epoch 212/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2280 - mean_squared_error: 0.2280 - val_loss: 0.2239 - val_mean_squared_error: 0.2239
# Epoch 213/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2228 - mean_squared_error: 0.2228 - val_loss: 0.1774 - val_mean_squared_error: 0.1774
# Epoch 214/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2109 - mean_squared_error: 0.2109 - val_loss: 0.1748 - val_mean_squared_error: 0.1748
# Epoch 215/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2173 - mean_squared_error: 0.2173 - val_loss: 0.1853 - val_mean_squared_error: 0.1853
# Epoch 216/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2148 - mean_squared_error: 0.2148 - val_loss: 0.1644 - val_mean_squared_error: 0.1644
# Epoch 217/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2171 - mean_squared_error: 0.2171 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 218/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2156 - mean_squared_error: 0.2156 - val_loss: 0.1628 - val_mean_squared_error: 0.1628
# Epoch 219/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2144 - mean_squared_error: 0.2144 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 220/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2184 - mean_squared_error: 0.2184 - val_loss: 0.1632 - val_mean_squared_error: 0.1632
# Epoch 221/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2231 - mean_squared_error: 0.2231 - val_loss: 0.1642 - val_mean_squared_error: 0.1642
# Epoch 222/500
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.2167 - mean_squared_error: 0.2167 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 223/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2115 - mean_squared_error: 0.2115 - val_loss: 0.1627 - val_mean_squared_error: 0.1627
# Epoch 224/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2193 - mean_squared_error: 0.2193 - val_loss: 0.1915 - val_mean_squared_error: 0.1915
# Epoch 225/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2166 - mean_squared_error: 0.2166 - val_loss: 0.1702 - val_mean_squared_error: 0.1702
# Epoch 226/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2161 - mean_squared_error: 0.2161 - val_loss: 0.1687 - val_mean_squared_error: 0.1687
# Epoch 227/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2178 - mean_squared_error: 0.2178 - val_loss: 0.1806 - val_mean_squared_error: 0.1806
# Epoch 228/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2187 - mean_squared_error: 0.2187 - val_loss: 0.1825 - val_mean_squared_error: 0.1825
# Epoch 229/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2218 - mean_squared_error: 0.2218 - val_loss: 0.1626 - val_mean_squared_error: 0.1626
# Epoch 230/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2151 - mean_squared_error: 0.2151 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 231/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2197 - mean_squared_error: 0.2197 - val_loss: 0.1789 - val_mean_squared_error: 0.1789
# Epoch 232/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2162 - mean_squared_error: 0.2162 - val_loss: 0.1789 - val_mean_squared_error: 0.1789
# Epoch 233/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2284 - mean_squared_error: 0.2284 - val_loss: 0.2112 - val_mean_squared_error: 0.2112
# Epoch 234/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2256 - mean_squared_error: 0.2256 - val_loss: 0.1652 - val_mean_squared_error: 0.1652
# Epoch 235/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2092 - mean_squared_error: 0.2092 - val_loss: 0.1623 - val_mean_squared_error: 0.1623
# Epoch 236/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.2175 - mean_squared_error: 0.2175 - val_loss: 0.1691 - val_mean_squared_error: 0.1691
# Epoch 237/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2106 - mean_squared_error: 0.2106 - val_loss: 0.1634 - val_mean_squared_error: 0.1634
# Epoch 238/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2128 - mean_squared_error: 0.2128 - val_loss: 0.1758 - val_mean_squared_error: 0.1758
# Epoch 239/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2117 - mean_squared_error: 0.2117 - val_loss: 0.1619 - val_mean_squared_error: 0.1619
# Epoch 240/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2142 - mean_squared_error: 0.2142 - val_loss: 0.1654 - val_mean_squared_error: 0.1654
# Epoch 241/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2149 - mean_squared_error: 0.2149 - val_loss: 0.1624 - val_mean_squared_error: 0.1624
# Epoch 242/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2055 - mean_squared_error: 0.2055 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 243/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2112 - mean_squared_error: 0.2112 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 244/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2052 - mean_squared_error: 0.2052 - val_loss: 0.1824 - val_mean_squared_error: 0.1824
# Epoch 245/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2071 - mean_squared_error: 0.2071 - val_loss: 0.1629 - val_mean_squared_error: 0.1629
# Epoch 301/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2041 - mean_squared_error: 0.2041 - val_loss: 0.1640 - val_mean_squared_error: 0.1640
# Epoch 302/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2067 - mean_squared_error: 0.2067 - val_loss: 0.2045 - val_mean_squared_error: 0.2045
# Epoch 303/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2085 - mean_squared_error: 0.2085 - val_loss: 0.1713 - val_mean_squared_error: 0.1713
# Epoch 304/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1970 - mean_squared_error: 0.1970 - val_loss: 0.1657 - val_mean_squared_error: 0.1657
# Epoch 305/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2120 - mean_squared_error: 0.2120 - val_loss: 0.1713 - val_mean_squared_error: 0.1713
# Epoch 306/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2011 - mean_squared_error: 0.2011 - val_loss: 0.1680 - val_mean_squared_error: 0.1680
# Epoch 307/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1994 - mean_squared_error: 0.1994 - val_loss: 0.1833 - val_mean_squared_error: 0.1833
# Epoch 308/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1978 - mean_squared_error: 0.1978 - val_loss: 0.1621 - val_mean_squared_error: 0.1621
# Epoch 309/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2081 - mean_squared_error: 0.2081 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 310/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1975 - mean_squared_error: 0.1975 - val_loss: 0.1638 - val_mean_squared_error: 0.1638
# Epoch 311/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2050 - mean_squared_error: 0.2050 - val_loss: 0.1706 - val_mean_squared_error: 0.1706
# Epoch 312/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1960 - mean_squared_error: 0.1960 - val_loss: 0.1666 - val_mean_squared_error: 0.1666
# Epoch 313/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2039 - mean_squared_error: 0.2039 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 314/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1952 - mean_squared_error: 0.1952 - val_loss: 0.1991 - val_mean_squared_error: 0.1991
# Epoch 315/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2041 - mean_squared_error: 0.2041 - val_loss: 0.1815 - val_mean_squared_error: 0.1815
# Epoch 316/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1987 - mean_squared_error: 0.1987 - val_loss: 0.1642 - val_mean_squared_error: 0.1642
# Epoch 317/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1952 - mean_squared_error: 0.1952 - val_loss: 0.1621 - val_mean_squared_error: 0.1621
# Epoch 318/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1997 - mean_squared_error: 0.1997 - val_loss: 0.1634 - val_mean_squared_error: 0.1634
# Epoch 319/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1921 - mean_squared_error: 0.1921 - val_loss: 0.1695 - val_mean_squared_error: 0.1695
# Epoch 320/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2048 - mean_squared_error: 0.2048 - val_loss: 0.1664 - val_mean_squared_error: 0.1664
# Epoch 321/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2014 - mean_squared_error: 0.2014 - val_loss: 0.1632 - val_mean_squared_error: 0.1632
# Epoch 322/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2017 - mean_squared_error: 0.2017 - val_loss: 0.1635 - val_mean_squared_error: 0.1635
# Epoch 323/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2020 - mean_squared_error: 0.2020 - val_loss: 0.1698 - val_mean_squared_error: 0.1698
# Epoch 324/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2045 - mean_squared_error: 0.2045 - val_loss: 0.1625 - val_mean_squared_error: 0.1625
# Epoch 325/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1915 - mean_squared_error: 0.1915 - val_loss: 0.1692 - val_mean_squared_error: 0.1692
# Epoch 326/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2012 - mean_squared_error: 0.2012 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 327/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1938 - mean_squared_error: 0.1938 - val_loss: 0.1807 - val_mean_squared_error: 0.1807
# Epoch 328/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1988 - mean_squared_error: 0.1988 - val_loss: 0.1637 - val_mean_squared_error: 0.1637
# Epoch 329/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2035 - mean_squared_error: 0.2035 - val_loss: 0.1672 - val_mean_squared_error: 0.1672
# Epoch 330/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1934 - mean_squared_error: 0.1934 - val_loss: 0.1738 - val_mean_squared_error: 0.1738
# Epoch 331/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1982 - mean_squared_error: 0.1982 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 332/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1981 - mean_squared_error: 0.1981 - val_loss: 0.1638 - val_mean_squared_error: 0.1638
# Epoch 333/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2026 - mean_squared_error: 0.2026 - val_loss: 0.1626 - val_mean_squared_error: 0.1626
# Epoch 334/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1993 - mean_squared_error: 0.1993 - val_loss: 0.1636 - val_mean_squared_error: 0.1636
# Epoch 335/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2069 - mean_squared_error: 0.2069 - val_loss: 0.1725 - val_mean_squared_error: 0.1725
# Epoch 336/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.1897 - mean_squared_error: 0.1897 - val_loss: 0.1703 - val_mean_squared_error: 0.1703
# Epoch 337/500
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.1952 - mean_squared_error: 0.1952 - val_loss: 0.1618 - val_mean_squared_error: 0.1618
# Epoch 338/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.1932 - mean_squared_error: 0.1932 - val_loss: 0.1625 - val_mean_squared_error: 0.1625
# Epoch 339/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.2043 - mean_squared_error: 0.2043 - val_loss: 0.1676 - val_mean_squared_error: 0.1676
# Epoch 340/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.1923 - mean_squared_error: 0.1923 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 341/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.1920 - mean_squared_error: 0.1920 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 342/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1988 - mean_squared_error: 0.1988 - val_loss: 0.1667 - val_mean_squared_error: 0.1667
# Epoch 343/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.1983 - mean_squared_error: 0.1983 - val_loss: 0.1713 - val_mean_squared_error: 0.1713
# Epoch 344/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.1946 - mean_squared_error: 0.1946 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 345/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.1942 - mean_squared_error: 0.1942 - val_loss: 0.1676 - val_mean_squared_error: 0.1676
# Epoch 346/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1977 - mean_squared_error: 0.1977 - val_loss: 0.1630 - val_mean_squared_error: 0.1630
# Epoch 347/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1827 - mean_squared_error: 0.1827 - val_loss: 0.1635 - val_mean_squared_error: 0.1635
# Epoch 401/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1906 - mean_squared_error: 0.1906 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 402/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1874 - mean_squared_error: 0.1874 - val_loss: 0.1804 - val_mean_squared_error: 0.1804
# Epoch 403/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1890 - mean_squared_error: 0.1890 - val_loss: 0.1645 - val_mean_squared_error: 0.1645
# Epoch 404/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1838 - mean_squared_error: 0.1838 - val_loss: 0.1666 - val_mean_squared_error: 0.1666
# Epoch 405/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1937 - mean_squared_error: 0.1937 - val_loss: 0.1627 - val_mean_squared_error: 0.1627
# Epoch 406/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1923 - mean_squared_error: 0.1923 - val_loss: 0.1622 - val_mean_squared_error: 0.1622
# Epoch 407/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1858 - mean_squared_error: 0.1858 - val_loss: 0.1626 - val_mean_squared_error: 0.1626
# Epoch 408/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1928 - mean_squared_error: 0.1928 - val_loss: 0.1835 - val_mean_squared_error: 0.1835
# Epoch 409/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.2025 - mean_squared_error: 0.2025 - val_loss: 0.1752 - val_mean_squared_error: 0.1752
# Epoch 410/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1885 - mean_squared_error: 0.1885 - val_loss: 0.1870 - val_mean_squared_error: 0.1870
# Epoch 411/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1880 - mean_squared_error: 0.1880 - val_loss: 0.1662 - val_mean_squared_error: 0.1662
# Epoch 412/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1812 - mean_squared_error: 0.1812 - val_loss: 0.1667 - val_mean_squared_error: 0.1667
# Epoch 413/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1912 - mean_squared_error: 0.1912 - val_loss: 0.1637 - val_mean_squared_error: 0.1637
# Epoch 414/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1885 - mean_squared_error: 0.1885 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 415/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1830 - mean_squared_error: 0.1830 - val_loss: 0.1623 - val_mean_squared_error: 0.1623
# Epoch 416/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1932 - mean_squared_error: 0.1932 - val_loss: 0.1619 - val_mean_squared_error: 0.1619
# Epoch 417/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1864 - mean_squared_error: 0.1864 - val_loss: 0.1668 - val_mean_squared_error: 0.1668
# Epoch 418/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.1865 - mean_squared_error: 0.1865 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 419/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1888 - mean_squared_error: 0.1888 - val_loss: 0.1729 - val_mean_squared_error: 0.1729
# Epoch 420/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1825 - mean_squared_error: 0.1825 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 421/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1875 - mean_squared_error: 0.1875 - val_loss: 0.1674 - val_mean_squared_error: 0.1674
# Epoch 422/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1885 - mean_squared_error: 0.1885 - val_loss: 0.1626 - val_mean_squared_error: 0.1626
# Epoch 423/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1801 - mean_squared_error: 0.1801 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 424/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1851 - mean_squared_error: 0.1851 - val_loss: 0.1636 - val_mean_squared_error: 0.1636
# Epoch 425/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.1894 - mean_squared_error: 0.1894 - val_loss: 0.1672 - val_mean_squared_error: 0.1672
# Epoch 426/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.1845 - mean_squared_error: 0.1845 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 427/500
# 1314/1314 [==============================] - 3s 3ms/step - loss: 0.1853 - mean_squared_error: 0.1853 - val_loss: 0.1808 - val_mean_squared_error: 0.1808
# Epoch 428/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.1908 - mean_squared_error: 0.1908 - val_loss: 0.1674 - val_mean_squared_error: 0.1674
# Epoch 429/500
# 1314/1314 [==============================] - 3s 2ms/step - loss: 0.1842 - mean_squared_error: 0.1842 - val_loss: 0.1623 - val_mean_squared_error: 0.1623
# Epoch 430/500
# 1314/1314 [==============================] - 2s 2ms/step - loss: 0.1841 - mean_squared_error: 0.1841 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 431/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1881 - mean_squared_error: 0.1881 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 432/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1867 - mean_squared_error: 0.1867 - val_loss: 0.1855 - val_mean_squared_error: 0.1855
# Epoch 433/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1873 - mean_squared_error: 0.1873 - val_loss: 0.1618 - val_mean_squared_error: 0.1618
# Epoch 434/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1913 - mean_squared_error: 0.1913 - val_loss: 0.1631 - val_mean_squared_error: 0.1631
# Epoch 435/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1842 - mean_squared_error: 0.1842 - val_loss: 0.1667 - val_mean_squared_error: 0.1667
# Epoch 436/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1837 - mean_squared_error: 0.1837 - val_loss: 0.1636 - val_mean_squared_error: 0.1636
# Epoch 437/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1836 - mean_squared_error: 0.1836 - val_loss: 0.1630 - val_mean_squared_error: 0.1630
# Epoch 438/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1883 - mean_squared_error: 0.1883 - val_loss: 0.1647 - val_mean_squared_error: 0.1647
# Epoch 439/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1867 - mean_squared_error: 0.1867 - val_loss: 0.1631 - val_mean_squared_error: 0.1631
# Epoch 440/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1856 - mean_squared_error: 0.1856 - val_loss: 0.1674 - val_mean_squared_error: 0.1674
# Epoch 441/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1852 - mean_squared_error: 0.1852 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 442/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1830 - mean_squared_error: 0.1830 - val_loss: 0.1629 - val_mean_squared_error: 0.1629
# Epoch 443/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1878 - mean_squared_error: 0.1878 - val_loss: 0.1797 - val_mean_squared_error: 0.1797
# Epoch 444/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1852 - mean_squared_error: 0.1852 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 445/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1837 - mean_squared_error: 0.1837 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 500/500
# 1314/1314 [==============================] - 2s 1ms/step - loss: 0.1732 - mean_squared_error: 0.1732 - val_loss: 0.1655 - val_mean_squared_error: 0.1655

# %%
# Evaluate Meta Model
yhat = meta_model_dnn.predict(meta_data_train)
meta_training_score = rmsle(y_train,yhat,exponential_transformation=True)
print('Meta-Model Training Score: {}'.format(meta_training_score))
# Out:
# Meta-Model Training Score: 0.40085972842241774

# %%
# As the simple Keras model did not perform as hoped, let's use a simple XGBRegressor model
xgb_meta = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                            learning_rate=0.05, max_depth=3, 
                            min_child_weight=1.7817, n_estimators=2200,
                            reg_alpha=0.4640, reg_lambda=0.8571,
                            subsample=0.5213, silent=1,
                            random_state =7, nthread = -1)

xgb_meta.fit(meta_data_train,y_train)
test_prediction = xgb_meta.predict(meta_data_train)

print('XGBR Meta Model Score: {}'.format(rmsle(y_train,test_prediction,exponential_transformation=True)))
# Out:
# XGBR Meta Model Score: 0.05060063591323374

# %% [markdown]
# ### Submission

# %%
# Although the final Meta model returned the best accuracy, let's try and submit the results from all models!
submission_df = pd.read_csv('test_processed.csv',index_col='Id')
submission_index = submission_df.index.to_list()

# %%
# Prepare test_data
submission_pipeline = make_pipeline(StandardScaler())
X_test = submission_pipeline.fit_transform(submission_df)
# Out:
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Marco\Anaconda3\envs\kaggle_housing_comp\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
# Create Predictions for submission
def create_submissions(models,meta_model,test_data):
    meta_data = np.empty((test_data.shape[0],len(models)))
    result_dict = {}
    for i,model in enumerate(models):
        yhat = np.exp(model.predict(test_data))
        yhat_meta = model.predict(test_data)
        meta_data[:,i] = yhat_meta
        result_dict[type(model).__name__] = yhat
    else:
        meta_predictions = np.exp(meta_model.predict(meta_data))
        result_dict['MetaModel'] = meta_predictions
    
    for key,value in result_dict.items():
        if key != 'GaussianMixture':
            export = pd.DataFrame(value,columns=['SalePrice'])
            export.index = submission_index
            export.index.name='Id'            
            export.to_csv(key+'.csv')

# %%
# Export Predictions
assert X_train.shape[1] == X_test.shape[1] and X_test.shape[0] == df_test.shape[0]

meta_data = create_submissions(models,xgb_meta,X_test)
